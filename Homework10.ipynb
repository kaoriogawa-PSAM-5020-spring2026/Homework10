# %% [markdown]
# # Homework10
#
# Exercises with text processing and NLP modeling
#
# ## Goals
#
# - Understand similarities and differences between the processes of working with text, images and tabular data
# - Practice with different methods of encoding and modeling text data
# - See different methods for extracting information or patterns from text datasets

# %% [markdown]
# ### Setup
#
# Run the following 2 cells to import all necessary libraries and helpers for this homework.

# %%
# !wget -q https://github.com/PSAM-5020-2026S-A/5020-utils/raw/main/src/data_utils.py
# !wget -q https://github.com/PSAM-5020-2026S-A/5020-utils/raw/main/src/text_utils.py

# %%
import matplotlib.cm as cm
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from data_utils import display_silhouette_plots, object_from_json_url
from text_utils import get_top_words

# %% [markdown]
# You can tell it's gonna be a good homework from the number of imports.
# # 🙃

# %% [markdown]
# ## Cheat Sheet
#
# There are lots of conversions in this homework between lists, strings, vectors, scores, etc...
#
# This list can help as a quick reference for the names of the functions and what they expect as input, and produce as output.
#
# These all operate on lists of _something_ and return lists of _something else_. But, here, let's just focus on the _type_ of the elements that go in these lists. Most of them will work on single elements, but not all.
#
# `TFIDF.fit_transform(string)` / `TFIDF.transform(string)` : string -> sparse vector
#
# `TFIDF.inverse_transform(vector)` : sparse vector -> list of words (NOT a string)
#
# `TFIDF.get_feature_names_out()` : None -> list of words (vocab of dataset)
#
# `TFIDF.get_feature_names_out()[idx]` : int (column index / word id) -> word
#
# `vector.toarray()` : vector -> regular array
#
# `get_top_words(vector, vocab, n_words=N)` : vector + list of all words + int -> list of top-N words in vector
#
# `argsort(metric)` : list of floats -> list of int indexes
#
# For example:
#
# To get the words in a sentence ordered by importance (most important first), we have to turn a string into a vector, then the vector into a regular list of scores, then the list into indexes, and, finally, fetch words from our vocab list using these indexes.
#
# ```py
# sentence = "a sentence goes here"
# num_words = len(sentence.split(" "))
# sentence_vct = TFIDF.transform([sentence])
# sentence_vct_list = sentence_vct.toarray()
# idx_by_importance = argsort(sentence_vct_list, reverse=True)[:num_words]
# TFIDF.get_feature_names_out()[idx_by_importance]
# ```
#
# For this particular example we could've used the `get_top_words()` function to get words ordered by importance:
#
# ```py
# sentence = "a sentence goes here"
# num_words = len(sentence.split(" "))
#
# get_top_words(
#   TFIDF.transform([sentence]),
#   TFIDF.get_feature_names_out(),
#   n_words=num_words
# )
# ```

# %% [markdown]
# ## Have protein, need seasoning
#
# Let's create a model to help us season our foods. In the end, what we want is a model that receives a short list of ingredients and returns a list of seasonings or complementary ingredients for our original ingredients list.
#
# In order to do that we need a dataset of recipes. We'll load that into a text dataset where each recipe is a document and the ingredients are our document *tokens*.
#
# Let's take a look at the recipe dataset and become familiar with the data and how it's organized.
#
# We'll load our recipes and do a bit of exploratory data analysis to look for patterns first to see if this kind of modeling makes any sense.
#
# ### Load Data
#
# Here's our dataset. Let's load it into an object for inspection:

# %%
DATA_PATH = "https://raw.githubusercontent.com/PSAM-5020-2026S-A/5020-utils/refs/heads/main/datasets/text/recipes/recipes_min16.json"
recipes_obj = object_from_json_url(DATA_PATH)

# %% [markdown]
# ### Look at Data
#
# How's the data organized?
#
# How many recipes do we have?
#
# Do all recipes have the same number of ingredients?
#
# Anything else stand out about the data?

# %%
# TODO: Look at Data here
print(recipes_obj)
# TODO: How many recipes
print(len(recipes_obj))

# TODO: How many ingredients do the shortest and longest recipes have?
length = [len(recipe["ingredients"]) for recipe in recipes_obj]
print(min (length))
print(max (length))
# Out:
# [{'id': 18009, 'ingredients': ['raisins', 'baking powder', 'egg', 'sugar', 'milk', 'flour']}, {'id': 35687, 'ingredients': ['parmesan cheese', 'salt', 'cornmeal', 'black pepper', 'sausage', 'olive oil', 'leeks', 'water']}, {'id': 38527, 'ingredients': ['salt', 'corn starch', 'butter', 'lemon juice', 'baking powder', 'heavy cream', 'peaches', 'sugar', 'flour']}, {'id': 41217, 'ingredients': ['corn starch', 'orange juice', 'rice', 'ginger', 'vinegar', 'vegetable oil', 'garlic', 'sriracha', 'sesame seeds', 'chicken broth', 'soy sauce', 'egg', 'onion', 'white pepper', 'orange zest', 'sugar']}, {'id': 42969, 'ingredients': ['cilantro', 'rice', 'ginger', 'garlic', 'yogurt', 'curry powder', 'onion', 'cumin']}, {'id': 44883, 'ingredients': ['mozzarella cheese', 'salt', 'parmesan cheese', 'rice', 'pasta', 'marinara sauce', 'basil']}, {'id': 19001, 'ingredients': ['salt', 'rice', 'chili', 'olives', 'jack cheese', 'cheddar cheese', 'water', 'sour cream']}, {'id': 16526, 'ingredients': ['salt', 'rice', 'vegetable oil', 'egg', 'cold water', 'buttermilk', 'flour']}, {'id': 47453, 'ingredients': ['salt', 'turmeric', 'rice', 'butter', 'water']}, {'id': 42478, 'ingredients': ['salt', 'potatoes', 'shallots', 'vinegar', 'lentils', 'black pepper', 'parsnips', 'chicken broth', 'carrots', 'olive oil', 'bay', 'celery']}, {'id': 16585, 'ingredients': ['salt', 'parmesan cheese', 'wine', 'rice', 'butter', 'bacon', 'shallots', 'potatoes', 'herbs', 'pepper', 'garlic', 'nutmeg', 'olive oil', 'paprika', 'vegetable stock']}, {'id': 26245, 'ingredients': ['lime', 'lemongrass', 'hot water', 'fish sauce', 'chili', 'serrano pepper', 'ginger', 'garlic', 'coriander', 'basil', 'mint', 'scallions', 'sugar']}, {'id': 38516, 'ingredients': ['salt', 'toasted sesame seeds', 'toasted sesame oil', 'red pepper', 'rice', 'egg', 'ginger', 'vinegar', 'honey', 'baking soda', 'garlic', 'soy sauce', 'apple juice', 'scallions', 'oil']}, {'id': 23696, 'ingredients': ['salt', 'cilantro', 'tomatillos', 'garlic', 'onion', 'serrano chile', 'avocado']}, {'id': 1384, 'ingredients': ['salt', 'cayenne pepper', 'corn starch', 'rice', 'ginger', 'honey', 'pepper', 'vegetable oil', 'garlic', 'sesame seeds', 'soy sauce', 'shrimp', 'onion']}, {'id': 15959, 'ingredients': ['salt', 'rice', 'chili', 'tomatoes', 'greenpepper', 'vegetable oil', 'onion', 'water']}, {'id': 46235, 'ingredients': ['salt', 'cilantro', 'turmeric', 'cumin seed', 'chili', 'potatoes', 'pepper', 'garlic', 'onion', 'masala', 'egg', 'wonton wrappers', 'ghee']}, {'id': 21181, 'ingredients': ['chicken', 'salt', 'black pepper', 'garlic', 'masala', 'onion', 'curry powder', 'olive oil', 'tomato paste', 'water']}, {'id': 9809, 'ingredients': ['ribs', 'salt', 'parsley', 'rice', 'red pepper', 'lemon juice', 'tomatoes', 'black pepper', 'garlic', 'chicken broth', 'thyme', 'shrimp', 'cayenne pepper', 'bay', 'scallions', 'sausage']}, {'id': 22982, 'ingredients': ['salt', 'parsley', 'celery', 'pepper', 'bell pepper', 'garlic', 'onion', 'turkey', 'onion', 'sausage', 'bay', 'oil', 'flour']}, {'id': 7050, 'ingredients': ['salt', 'rice', 'capers', 'lemon juice', 'black pepper', 'tuna', 'garlic', 'arugula', 'mayonnaise', 'oregano', 'anchovy', 'olive oil']}, {'id': 14760, 'ingredients': ['olives', 'rice', 'onion', 'chicken broth', 'paprika', 'saffron threads', 'shrimp', 'ham', 'olive oil', 'redpepper']}, {'id': 10649, 'ingredients': ['beef', 'salt', 'chili', 'butter', 'curry', 'tumeric', 'pepper', 'warm water', 'onion', 'egg', 'breadcrumbs', 'yeast', 'water', 'flour']}, {'id': 39931, 'ingredients': ['rice', 'peas', 'sesame oil', 'chicken stock', 'soy sauce', 'onion']}, {'id': 32935, 'ingredients': ['salt', 'wine', 'rice', 'olives', 'tomatoes', 'pepper', 'cooking spray', 'garlic', 'basil', 'oregano', 'olive oil', 'tomato paste', 'polenta', 'flour']}, {'id': 38267, 'ingredients': ['salt', 'eggplant', 'vinegar', 'pepper', 'garlic', 'chile', 'olive oil']}, {'id': 30512, 'ingredients': ['noodles', 'parmesan cheese', 'mozzarella cheese', 'cream cheese ...
# 5015
# 5
# 27

# %% [markdown]
# ### Create Input Features
#
# Our dataset doesn't really have to be a `DataFrame` here. It can, but it doesn't have to be.
#
# Each recipe right now is described as a list of ingredients, but what we really want is a list of *sentences*, where each *sentence* is a Python `string` with all of the ingredients for a given recipe.
#
# Instead of:<br>```["salt", "baking soda", "water", "mushroom"]```,
#
# we want:<br>```"salt baking soda water mushroom"```
#
# The `join()` function might help.
#
# Another thing to consider is wether we want to do anything special about multi-word ingredients, like *baking soda*.
#
# Do we want to let our vectorizer split that into two tokens, or do we want to guarantee that *baking* and *soda* always stay together?

# %%
# TODO: turn list of objects into list of strings
for recipe in recipes_obj:
  recipe["ingredients"] = " ".join(recipe["ingredients"])

recipes_obj
# Out:
# [{'id': 18009, 'ingredients': 'raisins baking powder egg sugar milk flour'},
#  {'id': 35687,
#   'ingredients': 'parmesan cheese salt cornmeal black pepper sausage olive oil leeks water'},
#  {'id': 38527,
#   'ingredients': 'salt corn starch butter lemon juice baking powder heavy cream peaches sugar flour'},
#  {'id': 41217,
#   'ingredients': 'corn starch orange juice rice ginger vinegar vegetable oil garlic sriracha sesame seeds chicken broth soy sauce egg onion white pepper orange zest sugar'},
#  {'id': 42969,
#   'ingredients': 'cilantro rice ginger garlic yogurt curry powder onion cumin'},
#  {'id': 44883,
#   'ingredients': 'mozzarella cheese salt parmesan cheese rice pasta marinara sauce basil'},
#  {'id': 19001,
#   'ingredients': 'salt rice chili olives jack cheese cheddar cheese water sour cream'},
#  {'id': 16526,
#   'ingredients': 'salt rice vegetable oil egg cold water buttermilk flour'},
#  {'id': 47453, 'ingredients': 'salt turmeric rice butter water'},
#  {'id': 42478,
#   'ingredients': 'salt potatoes shallots vinegar lentils black pepper parsnips chicken broth carrots olive oil bay celery'},
#  {'id': 16585,
#   'ingredients': 'salt parmesan cheese wine rice butter bacon shallots potatoes herbs pepper garlic nutmeg olive oil paprika vegetable stock'},
#  {'id': 26245,
#   'ingredients': 'lime lemongrass hot water fish sauce chili serrano pepper ginger garlic coriander basil mint scallions sugar'},
#  {'id': 38516,
#   'ingredients': 'salt toasted sesame seeds toasted sesame oil red pepper rice egg ginger vinegar honey baking soda garlic soy sauce apple juice scallions oil'},
#  {'id': 23696,
#   'ingredients': 'salt cilantro tomatillos garlic onion serrano chile avocado'},
#  {'id': 1384,
#   'ingredients': 'salt cayenne pepper corn starch rice ginger honey pepper vegetable oil garlic sesame seeds soy sauce shrimp onion'},
#  {'id': 15959,
#   'ingredients': 'salt rice chili tomatoes greenpepper vegetable oil onion water'},
#  {'id': 46235,
#   'ingredients': 'salt cilantro turmeric cumin seed chili potatoes pepper garlic onion masala egg wonton wrappers ghee'},
#  {'id': 21181,
#   'ingredients': 'chicken salt black pepper garlic masala onion curry powder olive oil tomato paste water'},
#  {'id': 9809,
#   'ingredients': 'ribs salt parsley rice red pepper lemon juice tomatoes black pepper garlic chicken broth thyme shrimp cayenne pepper bay scallions sausage'},
#  {'id': 22982,
#   'ingredients': 'salt parsley celery pepper bell pepper garlic onion turkey onion sausage bay oil flour'},
#  {'id': 7050,
#   'ingredients': 'salt rice capers lemon juice black pepper tuna garlic arugula mayonnaise oregano anchovy olive oil'},
#  {'id': 14760,
#   'ingredients': 'olives rice onion chicken broth paprika saffron threads shrimp ham olive oil redpepper'},
#  {'id': 10649,
#   'ingredients': 'beef salt chili butter curry tumeric pepper warm water onion egg breadcrumbs yeast water flour'},
#  {'id': 39931,
#   'ingredients': 'rice peas sesame oil chicken stock soy sauce onion'},
#  {'id': 32935,
#   'ingredients': 'salt wine rice olives tomatoes pepper cooking spray garlic basil oregano olive oil tomato paste polenta flour'},
#  {'id': 38267,
#   'ingredients': 'salt eggplant vinegar pepper garlic chile olive oil'},
#  {'id': 30512,
#   'ingredients': 'noodles parmesan cheese mozzarella cheese cream cheese red pepper cottage cheese cooking spray garlic basil prosciutto egg'},
#  {'id': 26197,
#   'ingredients': 'salt warm water cooking spray olive oil yeast sugar flour'},
#  {'id': 47230,
#   'ingredients': 'salmon wine corn starch red pepper ginger black bean vegetable oil cooking spray garlic chicken broth soy sauce onion sugar'},
#  {'id': 39748,
#   'ingredients': 'salt rice tomatoes black pepper greenpepper garlic chicken stock thyme onion oil hot sauce'},
#  {'id': 41038,
#   'ingredients': 'corn starch egg whipping cream liver sugar milk chocolate'},
#  {'id': 45706,
#   'ingredients': 'salt napa cabbage chili pears radishes garlic onion water sugar'},
#  {'id': 23878,
#   'ingredients': 'red pepper rice zucchini eggplant tomatoes celery chickpeas onion basil paprika oregano vegetable broth feta cheese olive oil redpepper'},
#  {'id': 24075,
#  {'id': 48560,
#   'ingredients': 'beef red pepper ginger sesame oil honey black pepper garlic sesame seeds soy sauce onion sake sugar'},
#  {'id': 20810,
#   'ingredients': 'salt chili salsa tomatoes garlic oregano cumin chuck'},
#  {'id': 47745,
#   'ingredients': 'red pepper green pepper peas tomatoes pepper vegetable oil thyme onion ham water hot sauce'},
#  {'id': 37815,
#   'ingredients': 'lime noodles rice garlic rice paper cucumber carrots onion mint olive oil avocado'},
#  {'id': 5592,
#   'ingredients': 'ribs salt tomatoes basil carrots onion olive oil'},
#  {'id': 40247,
#   'ingredients': 'lemon butter egg apples rice flour sugar flour'},
#  {'id': 19792,
#   'ingredients': 'tortilla salt cilantro olives chili garlic lamb lime juice oregano cocoa powder tomato paste golden raisins water'},
#  {'id': 14365,
#   'ingredients': 'guacamole tortilla cilantro chili salsa greenpepper garlic vegetable oil onion turkey lime juice soy sauce worcestershire sauce cumin sour cream redpepper'},
#  {'id': 7163,
#   'ingredients': 'beef tortilla monterey jack pico de gallo cheddar cheese'},
#  {'id': 27505,
#   'ingredients': 'salt oyster sauce oil wine corn starch egg sesame oil honey black pepper greenpepper garlic meat onion soy sauce water redpepper'},
#  {'id': 817,
#   'ingredients': 'salt red pepper rice spinach black pepper cooking spray garlic bread chees mozzarella olive oil oil rosemary'},
#  {'id': 8471,
#   'ingredients': 'salt pistachios butter flour cake flour cherries sugar vanilla'},
#  {'id': 48250,
#   'ingredients': 'salt sugar baking soda cooking spray baking powder yellow corn meal margarine cumin redpepper buttermilk flour'},
#  {'id': 9413,
#   'ingredients': 'ribs salt beer poblano chiles rice butter corn kernels shallots tomatoes garlic tomato sauce chicken stock canola oil onion andouille bananas redpepper seasoning'},
#  {'id': 12097,
#   'ingredients': 'potatoes crab egg shrimp onion mayonaise creole mustard celery seasoning'},
#  {'id': 8416,
#   'ingredients': 'salt red beans rice potatoes tomatoes cooking spray garlic greenpepper vegetable broth oregano onion olive oil bay tomato paste sugar hot sauce'},
#  {'id': 14630,
#   'ingredients': 'cannellini beans red pepper olives capers tomatoes garlic basil anchovy olive oil'},
#  {'id': 25981,
#   'ingredients': 'tortilla rice black bean mexican cheese vegetable oil'},
#  {'id': 39964, 'ingredients': 'parsley wine shallots pepper onion shrimp bay'},
#  {'id': 28298,
#   'ingredients': 'cumin seed chili coconut vegetable oil mustard seeds yogurt'},
#  {'id': 1038,
#   'ingredients': 'walnuts shortening allspice butter black pepper cinnamon cloves baking powder baking soda cocoa powder brandy sugar milk flour'},
#  {'id': 8077,
#   'ingredients': 'salt butter flour baking powder egg sugar milk vanilla'},
#  {'id': 37141,
#   'ingredients': 'salt shortening butter baking soda warm water yeast sugar buttermilk flour'},
#  {'id': 9624,
#   'ingredients': 'tortilla salt chicken cream cheese spinach salsa black pepper vegetable oil cheddar cheese sour cream'},
#  {'id': 7265, 'ingredients': 'chicken salt parsley potatoes yogurt'},
#  {'id': 13046, 'ingredients': 'spaghetti black pepper garlic bread olive oil'},
#  {'id': 9867,
#   'ingredients': 'salt parmesan cheese red pepper butter bacon black pepper garlic chicken broth water onion shrimp half & half grits mushrooms flour'},
#  {'id': 29184,
#   'ingredients': 'salt lemon garlic artichokes mint olive oil water'},
#  {'id': 34783,
#   'ingredients': 'salt wine red pepper baguette parsley black pepper sage garlic lamb cooking spray thyme olive oil rosemary'},
#  {'id': 11112,
#   'ingredients': 'tortilla chicken cilantro chili onion cheddar cheese sour cream seasoning'},
#  {'id': 12859,
#   'ingredients': 'lime fish sauce lime zest chili lemon grass rice garlic beans coriander lime juice red curry paste onion chicken stock cumin coconut cream sugar'},
#  {'id': 9365,
#   'ingredients': 'parmesan cheese lemon juice worcestershire sauce garlic lettuce mayonaise bread olive oil dijon mustard'},
#  {'id': 46545,
#   'ingredients': 'parmesan cheese spinach pasta onion chicken broth bacon'},
#  {'id': 39690,
#   'ingredients': 'parmesan cheese wine rice butter parsley zucchini shallots garlic chicken broth water yellowpepper'},
#  {'id': 27311,
#   'ingredients': 'salt wine ginger vegetable oil garlic onion shrimp'},
#  {'id': 29248,
#   'ingredients': 'salt cilantro lemon juice black pepper cooking spray garlic lamb cumin paprika'},
#  {'id': 43142,
#   'ingredients': 'tortilla salt beef chili salsa tomatoes monterey jack cheese black pepper garlic refried beans onion onion cumin cheddar cheese sour cream paprika'},
#  {'id': 7574,
#   'ingredients': 'rice bell pepper onion cauliflower water seasoning'},
#  {'id': 40816,
#   'ingredients': 'cilantro chili lemon wedge black pepper garlic lamb lime juice soy sauce lime wedges olive oil sugar'},
#  {'id': 39726, 'ingredients': 'rice scallions ginger turkey water'},
#  {'id': 22140,
#   'ingredients': 'monterey jack cheese onion canola oil chicken broth sour cream butter pepper serrano chile salt cilantro rice black pepper cumin tortilla tomatillos garlic olive oil cayenne flour'},
#  {'id': 20860,
#   'ingredients': 'mozzarella cheese salt parmesan cheese eggplant marinara sauce vegetable oil basil egg breadcrumbs milk'},
#  {'id': 42494,
#   'ingredients': 'noodles salt parmesan cheese mozzarella cheese tomato sauce egg ricotta sausage olive oil'},
#  {'id': 15968,
#   'ingredients': 'shells black pepper garlic onion canola oil thyme carrots bay leeks celery'},
#  {'id': 20484,
#   'ingredients': 'noodles cilantro fish sauce beansprouts rice mint shrimp'},
#  {'id': 47182,
#   'ingredients': 'cilantro corn kernels rice chili tomatoes garlic onion chicken broth lime juice cilantro sprigs olive oil sour cream'},
#  {'id': 22528,
#   'ingredients': 'salt raspberries butter lemon juice ginger baking powder egg apples vanilla sugar flour'},
#  {'id': 3861,
#   'ingredients': 'lime ginger peas chicken broth shrimp green curry paste'},
#  {'id': 45040,
#   'ingredients': 'ribs orange cranberries orange juice ginger cloves apples water golden raisins sugar'},
#  {'id': 10097,
#   'ingredients': 'salt ice water allspice ginger sage pork thyme breadcrumbs white pepper'},
#  {'id': 12423,
#   'ingredients': 'chicken red pepper rice green pepper tomatoes saffron garlic onion chicken broth saffron threads olive oil'},
#  {'id': 39613,
#   'ingredients': 'salt cooking oil cilantro rice black pepper bay water'},
#  {'id': 18686,
#   'ingredients': 'goat cheese chile powder mayonaise lime wedges corn'},
#  {'id': 40093,
#  {'id': 45838,
#   'ingredients': 'tortilla beef rice salsa chicken soup refried beans cheddar cheese water seasoning'},
#  {'id': 3009,
#   'ingredients': 'salt black pepper garlic thyme oregano onion cayenne pepper paprika'},
#  {'id': 13370,
#   'ingredients': 'stock salt mozzarella cheese parmesan cheese wine parsley pasta butter black pepper onion olive oil mushrooms flour'},
#  {'id': 14110,
#   'ingredients': 'lime salt cilantro rice cumin cayenne pepper olive oil'},
#  {'id': 34880,
#   'ingredients': 'parmesan cheese pinenuts salt black pepper garlic basil olive oil'},
#  {'id': 32166,
#   'ingredients': 'cilantro coconut milk ginger black pepper vegetable oil garlic red curry paste lime juice peanut butter soy sauce chicken broth onion sugar'},
#  {'id': 30343,
#   'ingredients': 'ribs salt beef turnips potatoes pepper onion lard carrots egg water flour'},
#  {'id': 23269,
#   'ingredients': 'salmon lemon juice ginger sesame oil garlic sesame seeds soy sauce mustard sugar'},
#  {'id': 4561,
#   'ingredients': 'lime salt cabbage radishes red cabbage coriander carrots onion chilees olive oil'},
#  {'id': 49032, 'ingredients': 'white miso nori onion tofu water mushrooms'},
#  {'id': 22064,
#   'ingredients': 'salt parsley wine capers eggplant pepper black pepper garlic yogurt onion olive oil'},
#  {'id': 12060,
#   'ingredients': 'asparagus chicken hot water rice butter onion dijon mustard mushrooms milk'},
#  {'id': 47834,
#   'ingredients': 'chicken salt red pepper lemon cornmeal black pepper vegetable oil garlic ice cubes onion tea bags sugar flour'},
#  {'id': 25815,
#   'ingredients': 'salt red pepper vinegar black pepper pork sugar hot sauce'},
#  {'id': 19326,
#   'ingredients': 'salt five-spice powder pineapple rice water chestnuts pepper soy sauce carrots onion'},
#  {'id': 44078,
#   'ingredients': 'cilantro udon beansprouts chili lime rind peanut cooking spray red curry paste soy sauce redpepper lime juice shrimp onion sugar'},
#  {'id': 5350,
#   'ingredients': 'fish sauce shallots eggplant tomatoes pepper vinegar egg onion'},
#  {'id': 18309,
#   'ingredients': 'salt parsley lemon fettucine pepper zucchini garlic ricotta mint olive oil'},
#  {'id': 46871,
#   'ingredients': 'salt caraway seeds butter potatoes egg black pepper garlic onion chicken broth thyme turkey pumpkin olive oil bay sour cream paprika'},
#  {'id': 27300,
#   'ingredients': 'salt raspberries corn starch butter lemon juice blueberries baking soda peacheses baking powder nutmeg sour cream sugar flour'},
#  {'id': 41890,
#   'ingredients': 'tortilla beef tomatoes garlic onion oil seasoning'},
#  {'id': 11392,
#   'ingredients': 'parsley olives lemon juice capers black pepper cognac anchovy olive oil dijon mustard'},
#  {'id': 1354,
#   'ingredients': 'lime salt cilantro rice pepper red curry paste oil'},
#  {'id': 19097,
#   'ingredients': 'salt rice butter chicken broth thyme onion white pepper bay'},
#  {'id': 42113,
#   'ingredients': 'lemon olives tomatoes black pepper greenpepper cucumber feta cheese lettuce oregano onion olive oil redpepper'},
#  {'id': 24060,
#   'ingredients': 'cilantro rice chili fish sauce ginger garlic canola oil soy sauce basil mint sugar'},
#  {'id': 25849,
#   'ingredients': 'salt butter egg sauce vanilla cream of tartar cocoa powder sugar chocolate'},
#  {'id': 48093,
#   'ingredients': 'cilantro orange juice vinegar honey garlic olive oil dijon mustard'},
#  {'id': 48942,
#   'ingredients': 'salt potatoes black pepper garlic fish rosemary sprigs breadcrumbs olive oil'},
#  {'id': 44358,
#   'ingredients': 'tortilla salsa black bean cheddar cheese sour cream'},
#  {'id': 10553,
#   'ingredients': 'wine rice pepper spaghetti cooking spray tomato sauce onion mushrooms seasoning'},
#  {'id': 31670,
#   'ingredients': 'chicken salt potatoes vegetable oil garlic onion curry powder hot sauce'},
#  {'id': 22722, 'ingredients': 'orange wine vanilla beans coffee vodka sugar'},
#  {'id': 9910,
#   'ingredients': 'salt tomatoes black pepper garlic bread olive oil'},
#  {'id': 14236,
#   'ingredients': 'asparagus mozzarella cheese parmesan cheese salt cornmeal black pepper cooking spray garlic warm water thyme yeast pancetta flour'},
#  {'id': 23190,
#   'ingredients': 'lemongrass cilantro fish sauce rice serrano pepper galangal garlic lime juice kaffir lime onion water'},
#  {'id': 44794,
#   'ingredients': 'salt wine red pepper vegetable oil onion collard greens bacon'},
#  {'id': 39419, 'ingredients': 'rice cinnamon sticks cinnamon sugar milk'},
#  {'id': 42270,
#   'ingredients': 'beef salt black pepper garlic onion carrots scallions sugar'},
#  {'id': 37208,
#   'ingredients': 'tortilla chili potatoes vegetable oil garlic onion soy sauce cumin cayenne pepper cheddar cheese kidney beans water mustard'},
#  {'id': 29953,
#   'ingredients': 'mozzarella cheese pizza sauce parmesan cheese pepperoni olive oil seasoning pizza crust'},
#  {'id': 16387, 'ingredients': 'egg sesame oil soy sauce water sugar'},
#  {'id': 1868,
#   'ingredients': 'kalamata salt onion olive oil yeast sugar rosemary flour'},
#  {'id': 47128,
#   'ingredients': 'salt kalamata pepperoni lemon juice tomatoes black pepper greenpepper cucumber lettuce oregano feta cheese onion olive oil'},
#  {'id': 44303,
#   'ingredients': 'beef vinegar onion soy sauce egg breadcrumbs water sugar flour'},
#  {'id': 20318,
#   'ingredients': 'red pepper orange juice rice hoisin sauce ginger vegetable oil chicken broth soy sauce tofu'},
#  {'id': 7513,
#   'ingredients': 'salt tomatoes pepper spaghetti garlic tomato sauce basil oregano sausage bay seasoning'},
#  {'id': 13261,
#   'ingredients': 'parmesan cheese salt black pepper garlic meat pork egg breadcrumbs milk'},
#  {'id': 31103,
#   'ingredients': 'chicken corn starch red pepper butter green pepper onion chicken broth ham olive oil tarragon'},
#  {'id': 5318, 'ingredients': 'juice ice cubes yogurt mango milk'},
#  {'id': 23962,
#   'ingredients': 'chicken tortilla cilantro olives green chile onion cheddar cheese red enchilada sauce sour cream'},
#  {'id': 2084,
#   'ingredients': 'salt wine red pepper parsley pepper tomatoes mussels spaghetti lemon zest garlic saffron threads olive oil'},
#  {'id': 18960,
#   'ingredients': 'parmesan cheese rice butter chicken broth carrots egg mushroom onion tarragon'},
#  {'id': 15510,
#   'ingredients': 'salt butter baking soda baking powder yellow corn meal sesame seeds egg onion sugar buttermilk flour'},
#  {'id': 10510,
#   'ingredients': 'chili black bean pepper chicken stock pork soy sauce onion tofu water'},
#  {'id': 43403,
#   'ingredients': 'parmesan cheese butter cheese garlic parsnips nutmeg rosemary mushroom milk'},
#  {'id': 33309,
#   'ingredients': 'salt rice butter egg shallots ginger pepper cognac cloves heavy cream'},
#  {'id': 6689,
#   'ingredients': 'salt kernel corn baking soda cooking spray vegetable oil yellow corn meal baking powder egg cumin buttermilk flour'},
#  {'id': 48687,
#   'ingredients': 'chicken parmesan cheese salt spinach butter potatoes black pepper garlic onion chicken broth basil carrots olive oil half & half celery flour'},
#  {'id': 9880,
#   'ingredients': 'parmesan cheese salt wine rice crackers parsley sprigs tomatoes black pepper cooking spray garlic linguine oregano onion'},
#  {'id': 25590,
#   'ingredients': 'noodles cheese tomatoes garlic onion egg bacon'},
#  {'id': 21842, 'ingredients': 'salt chili lime juice mayonaise avocado milk'},
#  {'id': 27151,
#   'ingredients': 'chicken salt turmeric chili potatoes curry vinegar pepper tomatoes coconut milk garlic mustard seeds onion masala fennel seeds coriander powder water oil'},
#  {'id': 35928,
#   'ingredients': 'salt cannellini beans rice lemon juice fennel bulb dill pepper leeks garlic lamb onion tomato juice bread crumb egg oregano artichokes bay water'},
#  {'id': 47060,
#   'ingredients': 'raisins salt caraway seeds baking powder egg sugar buttermilk flour'},
#  {'id': 16769, 'ingredients': 'salt wine potatoes onion egg olive oil'},
#  {'id': 12515,
#   'ingredients': 'salt baking soda vegetable oil yellow corn meal onion baking powder egg cayenne pepper sugar buttermilk flour'},
#  ...]

# %% [markdown]
# ### Encode Data
#
# The fun part.
#
# Let's vectorize our list of ingredient strings into a sparse document matrix using `CountVectorizer` or `TfidfVectorizer`.
#
# The resulting matrix will have one row for each recipe, and the columns will encode the ingredients.

# %%
# TODO: Vectorize ingredients from our recipe list
mCV = CountVectorizer()
recipes_vct = mCV.fit_transform([recipe["ingredients"] for recipe in recipes_obj])


# TODO: How many words are in our vocabulary?
vocab = mCV.get_feature_names_out()
display(vocab)
len(get_top_words(recipes_vct, vocab))
# Out:
# array(['adobo', 'agave', 'allspice', 'almond', 'amchur', 'american',
#        'ancho', 'anchovy', 'andouille', 'angel', 'anise', 'apple',
#        'apples', 'apricot', 'artichoke', 'artichokes', 'arugula',
#        'asafoetida', 'asiago', 'asian', 'asparagus', 'avocado', 'bacon',
#        'bags', 'baguette', 'baking', 'bamboo', 'bananas', 'base', 'basil',
#        'bay', 'bean', 'beans', 'beansprouts', 'beef', 'beer', 'beets',
#        'bell', 'belly', 'bird', 'biscuits', 'black', 'blackberries',
#        'blueberries', 'boiling', 'bok', 'bonito', 'bouillon', 'bourbon',
#        'bow', 'brandy', 'bread', 'breadcrumbs', 'broccoli', 'broth',
#        'brown', 'bulb', 'butt', 'butter', 'buttermilk', 'butternut',
#        'cabbage', 'cachaca', 'cake', 'cannellini', 'canola', 'capers',
#        'caraway', 'cardamom', 'carrots', 'cashew', 'cashews', 'catfish',
#        'cauliflower', 'cayenne', 'celery', 'chard', 'cheddar', 'chees',
#        'cheese', 'cherries', 'chestnuts', 'chicken', 'chickpeas', 'chile',
#        'chilees', 'chiles', 'chili', 'chipotle', 'chipotles', 'chives',
#        'chocolate', 'chops', 'chorizo', 'choy', 'chuck', 'cilantro',
#        'cinnamon', 'clam', 'clams', 'clove', 'cloves', 'cocoa', 'coconut',
#        'cod', 'coffee', 'cognac', 'cold', 'collard', 'condensed',
#        'cookies', 'cooking', 'coriander', 'corn', 'cornflour', 'cornmeal',
#        'cotija', 'cottage', 'couscous', 'crab', 'crabmeat', 'crackers',
#        'cranberries', 'crawfish', 'cream', 'creole', 'crumb', 'crust',
#        'crème', 'cubes', 'cucumber', 'cumin', 'currant', 'curry',
#        'daikon', 'dashi', 'de', 'dijon', 'dill', 'dipping', 'double',
#        'dough', 'doughs', 'dressing', 'egg', 'eggplant', 'eggplants',
#        'elbow', 'enchilada', 'escarole', 'espresso', 'fat', 'fennel',
#        'fenugreek', 'feta', 'fettucine', 'file', 'finely', 'fish', 'five',
#        'flakes', 'flank', 'flour', 'fontina', 'fraîche', 'fruit',
#        'galangal', 'gallo', 'garbanzo', 'garlic', 'gelatin', 'ghee',
#        'ginger', 'gingerroot', 'goat', 'gochujang', 'golden', 'grass',
#        'grating', 'green', 'greenpepper', 'greens', 'grits', 'gruyere',
#        'gruyère', 'guacamole', 'guajillo', 'hair', 'half', 'halibut',
#        'halves', 'ham', 'harina', 'hazelnuts', 'heavy', 'herbs', 'hoisin',
#        'honey', 'horseradish', 'hot', 'husks', 'ice', 'in', 'italian',
#        'jack', 'jicama', 'juice', 'kaffir', 'kalamata', 'kale', 'kasuri',
#        'kernel', 'kernels', 'ketchup', 'kidney', 'kimchi', 'konbu',
#        'lamb', 'lard', 'lean', 'leaves', 'leeks', 'lemon', 'lemongrass',
#        'lentils', 'lettuce', 'lime', 'linguine', 'liqueur', 'liver',
#        'lobster', 'loin', 'macaroni', 'mace', 'mango', 'maple',
#        'margarine', 'marinara', 'marjoram', 'masa', 'masala',
#        'mascarpone', 'mayonaise', 'mayonnaise', 'mayonnaisee', 'meal',
#        'meat', 'methi', 'mexican', 'milk', 'mint', 'mirin', 'miso',
#        'molasses', 'monterey', 'morsels', 'mozzarella', 'mung',
#        'mushroom', 'mushrooms', 'mussels', 'mustard', 'napa', 'nectar',
#        'noodles', 'nori', 'nutmeg', 'nuts', 'oats', 'of', 'oil', 'okra',
#        'olive', 'olives', 'onion', 'orange', 'orangepepper', 'oranges',
#        'oregano', 'orzo', 'oyster', 'oysters', 'pancetta', 'paneer',
#        'paper', 'paprika', 'parmesan', 'parsley', 'parsnips', 'pasta',
#        'paste', 'pastry', 'peaches', 'peacheses', 'peanut', 'pears',
#        'peas', 'pecan', 'pecans', 'peel', 'penne', 'pepper', 'pepperoni',
#        'pesto', 'phyllo', 'pico', 'piecrusts', 'pimentos', 'pineapple',
#        'pinenuts', 'pinto', 'pistachios', 'pizza', 'poblano', 'pods',
#        'polenta', 'poppy', 'pork', 'potatoes', 'powder', 'prawns',
#        'prosciutto', 'provolone', 'prunes', 'puff', 'pumpkin', 'pure',
#        'purée', 'quinoa', 'radicchio', 'radishes', 'raisins', 'ranch',
#        'raspberries', 'red', 'redpepper', 'refried', 'rib', 'ribs',
#        'rice', 'ricotta', 'rigatoni', 'rind', 'roll', 'rolls', 'rosemary',
#        'rum', 'saffron', 'sage', 'sake', 'salad', 'salmon', 'salsa',
#        'salt', 'sauce', 'sauces', 'sausage', 'sausages', 'scallions',
#        'scallops', 'sea', 'seasoning', 'seed', 'seeds', 'semolina',
#        'serrano', 'sesame', 'shallots', 'sheets', 'shells', 'sherry',
#        'shiitake', 'shoots', 'short', 'shortening', 'shoulder', 'shrimp',
#        'sirloin', 'snapper', 'soda', 'soup', 'sour', 'soy', 'spaghetti',
#        'spice', 'spices', 'spinach', 'spray', 'sprigs', 'spring',
#        'sprouts', 'squash', 'squid', 'sriracha', 'star', 'starch',
#        'steak', 'stems', 'stew', 'sticks', 'stock', 'strawberries',
#        'sugar', 'sunflower', 'sweet', 'swiss', 'syrup', 'szechwan',
#        'tabasco', 'taco', 'tamarind', 'tarragon', 'tartar', 'tea', 'teas',
#        'tenderloin', 'tequila', 'threads', 'thyme', 'tie', 'tilapia',
#        'toasted', 'tofu', 'tomatillos', 'tomato', 'tomatoes', 'tortilla',
#        'tumeric', 'tuna', 'turkey', 'turmeric', 'turnips', 'udon',
#        'vanilla', 'vegetable', 'vegetables', 'verde', 'vermouth',
#        'vietnamese', 'vinaigrette', 'vinegar', 'vodka', 'wafers',
#        'walnuts', 'warm', 'water', 'watercress', 'wedge', 'wedges',
#        'wheat', 'whipped', 'whipping', 'whiskey', 'white', 'wine',
#        'wonton', 'worcestershire', 'wrappers', 'yeast', 'yellow',
#        'yellowpepper', 'yogurt', 'zest', 'zucchini'], dtype=object)
# 5015

# %%
recipes_vct[0].nonzero()
# Out:
# (array([0, 0, 0, 0, 0, 0, 0], dtype=int32),
#  array([331,  25, 319, 144, 402, 249, 162], dtype=int32))

# %% [markdown]
# ### Cluster Data
#
# Now that we have our recipes/documents vectorized we can study them a little bit, and look for patterns.
#
# What happens if we cluster our recipes ? What do the cluster centers represent ?
#
# When might this be useful ?

# %%
# TODO: cluster recipes
recipe_clusters = KMeans(n_clusters=5, random_state=800)
ingredients_km = recipe_clusters.fit_predict(recipes_vct)

# %% [markdown]
# ### Cluster Centers
#
# Use the `get_top_words()` function to decode the `cluster_centers` back into ingredients.

# %%
# TODO: Look at cluster centers
recipe_clusters.cluster_centers_
print(recipe_clusters.cluster_centers_.shape)
print(get_top_words(recipe_clusters.cluster_centers_, vocab, n_words=8))
# Out:
# (8, 464)
# [['sauce', 'garlic', 'oil', 'sugar', 'onion', 'fish', 'lime', 'rice'], ['salt', 'onion', 'pepper', 'garlic', 'butter', 'water', 'rice', 'juice'], ['pepper', 'salt', 'onion', 'garlic', 'oil', 'black', 'tomatoes', 'cumin'], ['oil', 'sauce', 'soy', 'sesame', 'garlic', 'pepper', 'onion', 'sugar'], ['flour', 'sugar', 'egg', 'salt', 'butter', 'baking', 'milk', 'powder'], ['cheese', 'parmesan', 'pepper', 'oil', 'salt', 'olive', 'garlic', 'black'], ['cheese', 'onion', 'cream', 'tortilla', 'cheddar', 'sour', 'chili', 'salt'], ['oil', 'olive', 'garlic', 'salt', 'onion', 'pepper', 'tomatoes', 'lemon']]

# %% [markdown]
# ### Interpretation
#
# <span style="color:hotpink">
# What do these cluster centers represent ?<br>
# Is there anything interesting about recipe cluster centers ?<br>
# </span>

# %% [markdown]
# <span style="color:hotpink;">EDIT THIS CELL WITH ANSWER</span>
# We have 8 clusters with about 464 text features each. <br>
# It could mean our dataset has 8 most representative ingredients. <br>
# Interestingly, some ingredients appear in different clusters such as garlic, salt, pepper, which seems to be natural considering almost all the recipes use some kinds of sauces or seasonings.

# %% [markdown]
# ### Plot Clusters
#
# Let's plot our clusters to see if we have to adjust any of the clustering parameters.
#
# Since we can't plot in $500$ dimensions, we should use `TruncatedSVD` to look at our clusters in $2D$ and $3D$.

# %%
# TODO: TruncatedSVD to reduce the dimensions of our feature space
svd = TruncatedSVD(n_components=5, random_state=1010)
recipe_svd = svd.fit_transform(recipes_vct)

# TODO: plot clusters

cluster_labels = recipe_clusters.labels_
fig, ax = plt.subplots(figsize=(5, 6))

scatter = ax.scatter(
    recipe_svd[:, 0],   
    recipe_svd[:, 1],   
    c=cluster_labels,   
    cmap="tab10",       
    alpha=0.7
)

ax.set_xlabel("Component 1")
ax.set_ylabel("Component 2")
ax.set_title("Recipe Clusters (SVD with 5 components)")
plt.colorbar(scatter, ax=ax, label="Cluster")
plt.show()

# %% [markdown]
# ### Interpretation
#
# <span style="color:hotpink">
# What does the graph look like ?<br>
# Are the clusters well-separated ?
# </span>

# %% [markdown]
# <span style="color:hotpink;">EDIT THIS CELL WITH ANSWER</span><br>
# In a graph, data seems to be condensed around the center. The clusters are overlapped with each other.

# %% [markdown]
# ### Plot Silhouette Plots
#
# We can also check the quality of our clustering by looking at the silhouette plots that we get from calling:<br>
# `display_silhouette_plots(vectors, clusters)`.

# %%
display_silhouette_plots(recipes_vct, recipe_clusters.labels_)

# %% [markdown]
# ### Interpretation
#
# <span style="color:hotpink">
# How many clusters did you end up with ?<br>
# How do they look ?<br>
# </span>

# %% [markdown]
# <span style="color:hotpink;">EDIT THIS CELL WITH ANSWER</span><br>
# I ended up with 5 clusters. I tested with 8 clusters and thought the silhouette didn't look good, then tested with 5, which didn't make the clustering any better...

# %% [markdown]
# ## Recipe Completion
#
# Ok. On to the main event.
#
# Let's create some recipes.
#
# We'll do this using a technique similar to what is used for movie/product recommendations. Given an initial set of ingredients, we'll look at recipes that have similar ingredients and "recommend" additional ingredients.
#
# We already have all of the recipes in our dataset encoded as `tf-idf` vectors. The rest of our algorithm will be something like:
# 1. Start with an initial set of ingredients
# 2. Encode ingredients
# 3. Find a set of recipes that are similar to our list of ingredients
# 4. Find common ingredients that are in the similar recipes, but not in our list of ingredients
# 5. Pick representative ingredient to add to recipe
# 6. Repeat
#
# Let's start.

# %% [markdown]
# ### 1. Initial list of ingredients
#
# This is just a string with ingredients:

# %%
recipe_seed_str = "tofu" # feel free to change this

# %% [markdown]
# ### 2. Encode ingredients
#
# Transform the string into a `tf-idf` vector using the `transofrm()` function from the pre-fitted `TfidfVectorizer` object:

# %%
# TODO: transform string into sparse vector

recipe_seed_vct = [] # change this

# %% [markdown]
# ### 3. Find similar recipes
#
# The meat of the algorithm. No pun intended.
#
# In order to find similar recipes, we'll first calculate the distance between our current list of ingredients and all recipes in our dataset.
#
# We can start with euclidean distance and later try other kinds, but the overall processing will be the same:
#
# 1. Start with an empty list to store distances
# 2. Loop over the `tf-idf` recipe vectors and for each vector:
#    1. Subtract the ingredient list
#    2. Square the difference (to square a sparse matrix `A`, use `A.multiply(A)`)
#    3. Sum the terms of the result
#    4. Take the square root of the sum
#    5. Append to distance list
# 3. Find the indices of the smallest distances (this operation is called `argsort` and will give us the indices of the recipes that are most similar to our list of ingredients)
# 4. Check the recipes to see if they are indeed similar (`inverse_transform()` the vectors at the indices calculated above)

# %%
# argsort a list (get sequence of indices that would sort the list)
# https://stackoverflow.com/a/3382369
def argsort(L, reverse=False):
  L = L[0] if len(L) == 1 else L
  return sorted(range(len(L)), key=L.__getitem__, reverse=reverse)

# %%
# TODO: list to keep distances
recipe_distances = []

# TODO: loop over vectors and append euclidean distances to list

# TODO: argsort list of distances to find indices of similar recipes

# TODO: check first 4 recipes

# %% [markdown]
# ### 4. Find ingredients to recommend
#
# We have a way to get a set of similar recipes with similar ingredients, and now want to find a *meaningful*, or *representative*, ingredient to add to our ingredients list.
#
# Let's consider ingredients in the $16$ most similar recipes. What we are trying to do is find an ingredient that is in a lot of these recipes, but not yet in our list of ingredients.
#
# There are many possible ways of doing this. We could count the number of times different ingredients show up in these $16$ recipes using Python dictionaries and/or sets, but what we're trying to do here is very similar to what a `TfidfVectorizer` does: calculate relative importance of terms in a series of documents.
#
# Let's re-encode these $16$ recipes using their own separate `TfidfVectorizer`, then sum the importance of each ingredient and look at ingredients with the highest importance scores.
#
# We could re-use the vectors/scores from the original `TfidfVectorizer`, but they're gonna be influenced by the relative frequencies of all of the ingredients that showed up in all of the recipes. Using a separate vectorizer is a little bit more precise.
#
# The steps we need to take are:
#
# 1. Separate the $16$ recipes most similar to our list of ingredients
#    1. We have lots of representations of our recipes, but `recipes` (list of strings) might be the easiest one to use here
# 2. Create a new `TfidfVectorizer` and encode the $16$ recipes
# 3. Sum the resulting vectors by column to get overall importance scores for each ingredient/token
# 4. Convert resulting vector to a list using `A.tolist()[0]`
# 5. `argsort` the importance scores to get sequence of ingredient indices ordered from most to least important
# 6. Find the most important ingredient that isn't on the ingredient list

# %%
# TODO: Get 16 most similar recipes

# TODO: Encode the 16 recipes

# TODO: Sum the recipe vectors by column to get ingredient importance scores

# TODO: Convert sparse vector to regular list with A.tolist()[0]

# TODO: argsort the importance scores

# TODO: Find most important ingredient not yet on the list of ingredients

# %% [markdown]
# ### 5. Add ingredient to recipe
#
# This is simply adding a word to `recipe_seed_str`

# %%
# TODO: add the first important ingredient to list of ingredients

# %% [markdown]
# ### 6. Repeat (Optional)
#
# Now we can repeat this process until we get an empty list of important ingredients:
# 1. Encode current recipe
# 2. Find similar recipes
# 3. Find important ingredients
# 4. Add important ingredient
#
# Might be helpful to define a couple of functions, like `find_similar_recipes()` and `find_important_ingredients()`...
#
# Only do this step if you're really curious about experimenting with generating unconventional ingredient lists. It's not going to be graded.

# %%
# TODO: Create find_similar_recipes(ingredients, recipes, vectorizer)

# TODO: Create find_important_ingredients(recipes)

# TODO: Create recipe by repeating calls to find_similar_recipes() and find_important_ingredients()
